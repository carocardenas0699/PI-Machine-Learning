# %%
import pyarrow as pa
import pyarrow.parquet as pq
import pandas as pd
import numpy as np

# %% [markdown]
# # Elaboracion de archivos para la API

# %% [markdown]
# Se crearon los DataFrames con la informacion justa para la implementacion de cada funcion requerida. Para cada funcion se determinaron variables criticas (ej. el parametro de entrada) que de ser nulas el registro correspondiente no tendria la iformacion minima para ser incluido en el analisis. De acuerdo con esto, se decidio eliminar estos registros.

# %% [markdown]
# ## Cargar tablas

# %%
games=pd.read_parquet("Archivos EDA/games_eda.parquet")

# %%
items=pd.read_parquet("Archivos EDA/items_eda.parquet")

# %%
reviews=pd.read_parquet("Archivos EDA/reviews_eda.parquet")

# %%
games
# Out:
#                                                    genres  \
# 88310       [Action, Casual, Indie, Simulation, Strategy]
# 88311                [Free to Play, Indie, RPG, Strategy]
# 88312   [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                         [Action, Adventure, Casual]
# 88314                                                None
# ...                                                   ...
# 120440              [Casual, Indie, Simulation, Strategy]
# 120441                          [Casual, Indie, Strategy]
# 120442                        [Indie, Racing, Simulation]
# 120443                                    [Casual, Indie]
# 120444                                               None
#
#                        item_name  \
# 88310        Lost Summoner Kitty
# 88311                  Ironbound
# 88312    Real Pool 3D - Poolians
# 88313                    弹炸人2222
# 88314              Log Challenge
# ...                          ...
# 120440            Colony On Mars
# 120441  LOGistICAL: South Africa
# 120442             Russian Roads
# 120443       EXIT 2 - Directions
# 120444               Maze Run VR
#
#                                                      tags  \
# 88310       [Strategy, Action, Indie, Casual, Simulation]
# 88311   [Free to Play, Strategy, Indie, RPG, Card Game...
# 88312   [Free to Play, Simulation, Sports, Casual, Ind...
# 88313                         [Action, Adventure, Casual]
# 88314                     [Action, Indie, Casual, Sports]
# ...                                                   ...
# 120440              [Strategy, Indie, Casual, Simulation]
# 120441                          [Strategy, Indie, Casual]
# 120442                        [Indie, Simulation, Racing]
# 120443  [Indie, Casual, Puzzle, Singleplayer, Atmosphe...
# 120444  [Early Access, Adventure, Indie, Action, Simul...
#
#                                                     specs  price  \
# 88310                                     [Single-player]   4.99
# 88311   [Single-player, Multi-player, Online Multi-Pla...   0.00
# 88312   [Single-player, Multi-player, Online Multi-Pla...   0.00
# 88313                                     [Single-player]   0.99
# 88314   [Single-player, Full controller support, HTC V...   2.99
# ...                                                   ...    ...
# 120440                [Single-player, Steam Achievements]   1.99
# 120441  [Single-player, Steam Achievements, Steam Clou...   4.99
# 120442  [Single-player, Steam Achievements, Steam Trad...   1.99
# 120443   [Single-player, Steam Achievements, Steam Cloud]   4.99
# 120444  [Single-player, Stats, Steam Leaderboards, HTC...   4.99
#
#         early_access   item_id                 developer  release_year
# 88310            0.0  761140.0                 Kotoshiro        2018.0
# 88311            0.0  643980.0          Secret Level SRL        2018.0
# 88312            0.0  670290.0              Poolians.com        2017.0
# 88313            0.0  767400.0                      彼岸领域        2017.0
# 88314            0.0  773570.0                      None           NaN
# ...              ...       ...                       ...           ...
# 120440           0.0  773640.0        Nikita "Ghost_RUS"        2018.0
# 120441           0.0  733530.0                    Sacada        2018.0
# 120442           0.0  610660.0  Laush Dmitriy Sergeevich        2018.0
# 120443           0.0  658870.0             xropi,stev3ns        2017.0
# 120444           1.0  681550.0                      None           NaN
#
# [32131 rows x 9 columns]

# %%
items
# Out:
#                    user_id   item_id                      item_name  playtime
# 0        76561197970982479      10.0                 Counter-Strike  0.100000
# 1        76561197970982479      20.0          Team Fortress Classic  0.000000
# 2        76561197970982479      30.0                  Day of Defeat  0.116667
# 3        76561197970982479      40.0             Deathmatch Classic  0.000000
# 4        76561197970982479      50.0      Half-Life: Opposing Force  0.000000
# ...                    ...       ...                            ...       ...
# 5170009  76561198329548331  346330.0                   BrainBread 2  0.000000
# 5170010  76561198329548331  373330.0                    All Is Dust  0.000000
# 5170011  76561198329548331  388490.0  One Way To Die: Steam Edition  0.050000
# 5170012  76561198329548331  521570.0          You Have 10 Seconds 2  0.066667
# 5170013  76561198329548331  519140.0                     Minds Eyes  0.050000
#
# [5073726 rows x 4 columns]

# %%
reviews
# Out:
#                  user_id   item_id  recommend  \
# 0      76561197970982479    1250.0       True
# 1      76561197970982479   22200.0       True
# 2      76561197970982479   43110.0       True
# 3                js41637  251610.0       True
# 4                js41637  227300.0       True
# ...                  ...       ...        ...
# 58426  76561198312638244      70.0       True
# 58427  76561198312638244  362890.0       True
# 58428        LydiaMorley  273110.0       True
# 58429        LydiaMorley     730.0       True
# 58430        LydiaMorley     440.0       True
#
#                               item_name  sentiment_analysis  \
# 0                         Killing Floor                   1
# 1                            Zeno Clash                   1
# 2                            Metro 2033                   2
# 3             Barbie™ Dreamhouse Party™                   1
# 4                Euro Truck Simulator 2                   1
# ...                                 ...                 ...
# 58426                         Half-Life                   1
# 58427                        Black Mesa                   1
# 58428     Counter-Strike Nexon: Zombies                   1
# 58429  Counter-Strike: Global Offensive                   2
# 58430                              None                   2
#
#                                                    words  word_count
# 0      [simple, yet, great, replayability, opinion, z...          44
# 1                           [unique, worth, playthrough]           7
# 2      [great, atmosphere, gunplay, bit, chunky, time...          40
# 3      [know, think, see, title, barbie, dreamhouse, ...         112
# 4      [simple, actually, not, simple, truck, driving...         117
# ...                                                  ...         ...
# 58426  [must, classic, steam, definitely, worth, buying]           9
# 58427  [game, perfect, remake, original, half, life, ...          92
# 58428  [much, fun, plaing, collecting, resources, xd,...          20
# 58429                                                 []           1
# 58430                                        [much, fun]           4
#
# [58431 rows x 7 columns]

# %% [markdown]
# ## Creacion de archivos

# %% [markdown]
# ### def developer( desarrollador : str )

# %% [markdown]
# Cantidad de items y porcentaje de contenido Free por año según empresa desarrolladora. <br><br>
# Ejemplo de retorno: <br>
# | Año   | Cantidad de items | Contenido Free |
# | ----- | ----------------- | -------------- |
# | 2023  | 50                | 27%            |
# | 2022  | 45                | 25%            |
# <br>
#
# Columnas necesarias:
# - developer (games)
# - release_year (games)
# - price (games)
# - item_id (games)

# %%
def_developer = games[['developer','item_id','release_year','price']]
def_developer.drop(def_developer[def_developer['developer'].isnull()].index,inplace=True)
def_developer
# Out:
# C:\Users\Carolina\AppData\Local\Temp\ipykernel_55196\893622525.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   def_developer.drop(def_developer[def_developer['developer'].isnull()].index,inplace=True)
#                        developer   item_id  release_year  price
# 88310                  Kotoshiro  761140.0        2018.0   4.99
# 88311           Secret Level SRL  643980.0        2018.0   0.00
# 88312               Poolians.com  670290.0        2017.0   0.00
# 88313                       彼岸领域  767400.0        2017.0   0.99
# 88315        Trickjump Games Ltd  772540.0        2018.0   3.99
# ...                          ...       ...           ...    ...
# 120439           Bidoniera Games  745400.0        2018.0   1.99
# 120440        Nikita "Ghost_RUS"  773640.0        2018.0   1.99
# 120441                    Sacada  733530.0        2018.0   4.99
# 120442  Laush Dmitriy Sergeevich  610660.0        2018.0   1.99
# 120443             xropi,stev3ns  658870.0        2017.0   4.99
#
# [28834 rows x 4 columns]

# %%
def_developer.isnull().sum()
# Out:
# developer          0
# item_id            0
# release_year     122
# price           1235
# dtype: int64

# %% [markdown]
# ### def userdata( User_id : str )

# %% [markdown]
# Debe devolver cantidad de dinero gastado por el usuario, el porcentaje de recomendación en base a reviews.recommend y cantidad de items. <br><br>
# Ejemplo de retorno: <br>
# {"Usuario X" : us213ndjss09sdf, "Dinero gastado": 200 USD, "% de recomendación": 20%, "cantidad de items": 5}
# <br><br>
# Columnas necesarias:
# - user_id (reviews)
# - recommend (reviews)
# - item_id (reviews, games)
# - price (games)

# %%
def_userdata = reviews[['user_id','item_id','recommend']]
def_userdata = def_userdata.merge(games[['item_id','price']],on='item_id')
def_userdata
# Out:
#                  user_id   item_id  recommend  price
# 0      76561197970982479    1250.0       True  19.99
# 1      76561197970982479   22200.0       True   9.99
# 2                js41637  227300.0       True  19.99
# 3                js41637  239030.0       True   9.99
# 4              evcentric  248820.0       True   9.99
# ...                  ...       ...        ...    ...
# 53192  76561198312638244      70.0       True   9.99
# 53193  76561198312638244  362890.0       True  19.99
# 53194        LydiaMorley  273110.0       True   0.00
# 53195        LydiaMorley     730.0       True  14.99
# 53196        LydiaMorley     440.0       True   0.00
#
# [53197 rows x 4 columns]

# %%
def_userdata.isnull().sum()
# Out:
# user_id        0
# item_id        0
# recommend      0
# price        686
# dtype: int64

# %% [markdown]
# ### def UserForGenre( genero : str )

# %% [markdown]
# Debe devolver el usuario que acumula más horas jugadas para el género dado y una lista de la acumulación de horas jugadas por año de lanzamiento. <br><br>
# Ejemplo de retorno:<br>
# {"Usuario con más horas jugadas para Género X" : us213ndjss09sdf, "Horas jugadas":[{Año: 2013, Horas: 203}, {Año: 2012, Horas: 100}, {Año: 2011, Horas: 23}]}
# <br><br>
# Columnas necesarias:
# - user_id (items)
# - playtime (items)
# - item_id (items, games)
# - genres (games)
# - release_year (games)

# %%
def_userforgenre = items[['user_id','playtime','item_id']]
def_userforgenre = def_userforgenre.merge(games[['item_id','genres','release_year']],on='item_id')
def_userforgenre.drop(def_userforgenre[def_userforgenre['genres'].isnull()].index,inplace=True)
def_userforgenre
# Out:
#                    user_id   playtime   item_id  \
# 0        76561197970982479   0.100000      10.0
# 1        76561197970982479   0.000000      20.0
# 2        76561197970982479   0.116667      30.0
# 3        76561197970982479   0.000000      40.0
# 4        76561197970982479   0.000000      50.0
# ...                    ...        ...       ...
# 4233165  76561198329548331  11.283333  304930.0
# 4233166  76561198329548331   0.716667  227940.0
# 4233167  76561198329548331   0.000000  346330.0
# 4233169  76561198329548331   0.050000  388490.0
# 4233170  76561198329548331   0.066667  521570.0
#
#                                                     genres  release_year
# 0                                                 [Action]        2000.0
# 1                                                 [Action]        1999.0
# 2                                                 [Action]        2003.0
# 3                                                 [Action]        2001.0
# 4                                                 [Action]        1999.0
# ...                                                    ...           ...
# 4233165   [Action, Adventure, Casual, Free to Play, Indie]        2017.0
# 4233166  [Action, Free to Play, Indie, Massively Multip...        2016.0
# 4233167  [Action, Adventure, Free to Play, Indie, Early...        2016.0
# 4233169                          [Adventure, Free to Play]        2015.0
# 4233170                      [Casual, Free to Play, Indie]        2016.0
#
# [4144788 rows x 5 columns]

# %%
def_userforgenre.isnull().sum()
# Out:
# user_id            0
# playtime           0
# item_id            0
# genres             0
# release_year    6587
# dtype: int64

# %% [markdown]
# ### def best_developer_year( año : int )

# %% [markdown]
# Devuelve el top 3 de desarrolladores con juegos MÁS recomendados por usuarios para el año dado. (reviews.recommend = True y comentarios positivos) <br><br>
# Ejemplo de retorno: <br>
# [{"Puesto 1" : X}, {"Puesto 2" : Y},{"Puesto 3" : Z}]
# <br><br>
# Columnas necesarias:
# - developer (games)
# - release_year (games)
# - recommend (reviews)
# - sentiment_analysis (reviews)
# - item_id (reviews, games)

# %%
def_best_dev = games[['developer','item_id','release_year']]
def_best_dev = def_best_dev.merge(reviews[['item_id','recommend','sentiment_analysis']],on='item_id')
def_best_dev.drop(def_best_dev[(def_best_dev['developer'].isnull())|(def_best_dev['release_year'].isnull())].index,inplace=True)
def_best_dev
# Out:
#                  developer   item_id  release_year  recommend  \
# 0      Stainless Games Ltd  282010.0        1997.0       True
# 1                    Valve      70.0        1998.0       True
# 2                    Valve      70.0        1998.0       True
# 3                    Valve      70.0        1998.0       True
# 4                    Valve      70.0        1998.0       True
# ...                    ...       ...           ...        ...
# 53192                Valve      80.0        2004.0      False
# 53193                Valve      80.0        2004.0       True
# 53194                Valve      80.0        2004.0       True
# 53195                Valve      80.0        2004.0       True
# 53196                Valve      80.0        2004.0       True
#
#        sentiment_analysis
# 0                       1
# 1                       1
# 2                       1
# 3                       1
# 4                       1
# ...                   ...
# 53192                   1
# 53193                   1
# 53194                   1
# 53195                   1
# 53196                   1
#
# [49562 rows x 5 columns]

# %%
def_best_dev.isnull().sum()
# Out:
# developer             0
# item_id               0
# release_year          0
# recommend             0
# sentiment_analysis    0
# dtype: int64

# %% [markdown]
# ### def developer_reviews_analysis( desarrolladora : str )

# %% [markdown]
# Según el desarrollador, se devuelve un diccionario con el nombre del desarrollador como llave y una lista con la cantidad total de registros de reseñas de usuarios que se encuentren categorizados con un análisis de sentimiento como valor positivo o negativo. <br><br>
# Ejemplo de retorno: <br>
# {'Valve' : [Negative = 182, Positive = 278]}
# <br><br>
# Columnas necesarias:
# - developer (games)
# - item_id (games, reviews)
# - sentiment_analysis (reviews)

# %%
def_dev_rev = games[['developer','item_id']]
def_dev_rev = def_dev_rev.merge(reviews[['item_id','sentiment_analysis']],on='item_id')
def_dev_rev.drop(def_dev_rev[def_dev_rev['developer'].isnull()].index,inplace=True)
def_dev_rev
# Out:
#                  developer   item_id  sentiment_analysis
# 0      Stainless Games Ltd  282010.0                   1
# 1                    Valve      70.0                   1
# 2                    Valve      70.0                   1
# 3                    Valve      70.0                   1
# 4                    Valve      70.0                   1
# ...                    ...       ...                 ...
# 53192                Valve      80.0                   1
# 53193                Valve      80.0                   1
# 53194                Valve      80.0                   1
# 53195                Valve      80.0                   1
# 53196                Valve      80.0                   1
#
# [49626 rows x 3 columns]

# %%
def_dev_rev.isnull().sum()
# Out:
# developer             0
# item_id               0
# sentiment_analysis    0
# dtype: int64

# %% [markdown]
# ## Exportar archivos finales

# %%
pq.write_table(pa.Table.from_pandas(def_developer),'Archivos API/def_developer.parquet')
pq.write_table(pa.Table.from_pandas(def_userdata),'Archivos API/def_userdata.parquet')
pq.write_table(pa.Table.from_pandas(def_userforgenre),'Archivos API/def_userforgenre.parquet')
pq.write_table(pa.Table.from_pandas(def_best_dev),'Archivos API/def_best_dev.parquet')
pq.write_table(pa.Table.from_pandas(def_dev_rev),'Archivos API/def_dev_rev.parquet')
